# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\devan\Desktop\CODING\Diwali_T-Shirt_Dataset.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      48 non-null     int64
#  1   CustomerName    48 non-null     object
#  2   Gender          48 non-null     object
#  3   Age             48 non-null     int64
#  4   Marital_Status  48 non-null     object
#  5   State           48 non-null     object
#  6   City            48 non-null     object
#  7   Occupation      48 non-null     object
#  8   Product_Name    48 non-null     object
#  9   Price           48 non-null     int64
#  10  Quantity_Sold   48 non-null     int64
#  11  Discount(%)     48 non-null     int64
#  12  PaymentMode     48 non-null     object
#  13  Date            48 non-null     object
#  14  Total_Amount    48 non-null     float64
#  15  Profit          48 non-null     float64
# dtypes: float64(2), int64(5), object(9)
# memory usage: 6.1+ KB
# ...

# %%
daily_sales = df.groupby('Date')['Total_Amount'].sum()
plt.figure(figsize=(10,7))
plt.plot(daily_sales.index, daily_sales.values, marker='o', color='lime',)
plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales (₹)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
age_group_sales = df.groupby('Age')['Total_Amount'].sum()

plt.bar(age_group_sales.index, age_group_sales.values, color='violet')
plt.title(' Sales by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Sales (₹)')
plt.show()

# %%
gender_sales = df.groupby('Gender')['Total_Amount'].sum()

plt.bar(gender_sales.index, gender_sales.values, color=['lightcoral', 'mediumseagreen'])
plt.title('🚻 Sales by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Sales (₹)')
plt.show()
# Out:
# C:\Users\devan\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128699 (\N{RESTROOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
payment_sales = df.groupby('PaymentMode')['Total_Amount'].sum()

plt.bar(payment_sales.index, payment_sales.values, color=['#ffb703', '#219ebc', '#8ecae6'])
plt.title('💳 Payment Mode vs Total Sales')
plt.xlabel('Payment Method')
plt.ylabel('Total Sales (₹)')
plt.show()
# Out:
# C:\Users\devan\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128179 (\N{CREDIT CARD}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
revenue = df['Total_Amount'].sum()
profit = df['Profit'].sum()

plt.bar(['Revenue', 'Profit'], [revenue, profit], color=['teal', 'orange'])
plt.title('💰 Total Revenue vs Profit')
plt.ylabel('Amount (₹)')
plt.show()
# Out:
# C:\Users\devan\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
state_sales = df.groupby('State')['Total_Amount'].sum().sort_values(ascending=False).head(5)

plt.bar(state_sales.index, state_sales.values, color='mediumpurple')
plt.title('🗺️ Top 5 States by Sales')
plt.ylabel('Total Sales (₹)')
plt.show()
# Out:
# C:\Users\devan\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128506 (\N{WORLD MAP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
diwali_date = '2024-11-02'
dhanteras_date = '2024-10-31'

sales_diwali = df[df['Date'] == diwali_date]['Total_Amount'].sum()
sales_dhanteras = df[df['Date'] == dhanteras_date]['Total_Amount'].sum()

print("Sales on Diwali:", sales_diwali)
print("Sales on Dhanteras:", sales_dhanteras)

fig, ax = plt.subplots()
bars = ax.bar(['Diwali', 'Dhanteras'], [sales_diwali, sales_dhanteras], color=['gold', 'orange'])
ax.bar_label(bars, fmt='₹%.0f')
plt.title('   Sales Comparison: Diwali vs Dhanteras')
plt.ylabel('Total Sales (₹)')
plt.show()
# Out:
# Sales on Diwali: 25679.089999999997
# Sales on Dhanteras: 23995.69
